# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("movies.csv", index_col = 0)

# %%
directors = pd.read_csv("directors.csv", index_col = 0)

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# ## Checking the shape of the dataframes

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %% [markdown]
# ## Extracting first 5 and bottom 5 records from the dataframes

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
movies.tail()
# Out:
#          id  budget  popularity  revenue           title  vote_average  \
# 4736  48363       0           3   321952  The Last Waltz           7.9
# 4743  48370   27000          19  3151130          Clerks           7.4
# 4748  48375       0           7        0         Rampage           6.0
# 4749  48376       0           3        0         Slacker           6.4
# 4768  48395  220000          14  2040920     El Mariachi           6.6
#
#       vote_count  director_id  year month      day
# 4736          64         4809  1978   May   Monday
# 4743         755         5369  1994   Sep  Tuesday
# 4748         131         5148  2009   Aug   Friday
# 4749          77         5535  1990   Jul   Friday
# 4768         238         5097  1992   Sep   Friday

# %%
directors.tail()
# Out:
#          director_name    id gender
# 2344     Shane Carruth  7106   Male
# 2345  Neill Dela Llana  7107    NaN
# 2346       Scott Smith  7108    NaN
# 2347       Daniel Hsia  7109   Male
# 2348  Brian Herzlinger  7110   Male

# %% [markdown]
# ## Basic info of the dataframes

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 4768
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 137.3+ KB

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 73.4+ KB

# %%
movies.describe()
# Out:
#                  id        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1465.000000  1465.000000  1465.000000
# mean    1146.396587  5040.192491  2002.615017
# std     1578.077438   258.059631     8.680141
# min        1.000000  4762.000000  1976.000000
# 25%      216.000000  4845.000000  1998.000000
# ...

# %%
movies.describe(include = "object")
# Out:
#          title month     day
# count     1465  1465    1465
# unique    1465    12       7
# top     Avatar   Dec  Friday
# freq         1   193     654

# %%
directors.describe()
# Out:
#                 id
# count  2349.000000
# mean   5936.000000
# std     678.242213
# min    4762.000000
# 25%    5349.000000
# 50%    5936.000000
# 75%    6523.000000
# max    7110.000000

# %%
directors.describe(include = "object")
# Out:
#         director_name gender
# count            2349   1724
# unique           2349      2
# top     James Cameron   Male
# freq                1   1574

# %% [markdown]
# ## Checking for unique values

# %%
movies.nunique()
# Out:
# id              1465
# budget           201
# popularity       128
# revenue         1267
# title           1465
# vote_average      51
# vote_count      1019
# director_id      199
# year              41
# month             12
# day                7
# dtype: int64

# %%
directors.nunique()
# Out:
# director_name    2349
# id               2349
# gender              2
# dtype: int64

# %% [markdown]
# ## Checking for duplicates

# %%
duplicates_movies = movies.duplicated()
duplicates_movies
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 4736    False
# 4743    False
# 4748    False
# 4749    False
# 4768    False
# Length: 1465, dtype: bool

# %%
if duplicates_movies.any():
    print("There are duplicates in the DataFrame.")
else:
    print("No duplicates found in the DataFrame.")
# Out:
# No duplicates found in the DataFrame.

# %%
duplicates_directors = directors.duplicated()
duplicates_directors
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2344    False
# 2345    False
# 2346    False
# 2347    False
# 2348    False
# Length: 2349, dtype: bool

# %%
if duplicates_directors.any():
    print("There are duplicates in the DataFrame.")
else:
    print("No duplicates found in the DataFrame.")
# Out:
# No duplicates found in the DataFrame.

# %% [markdown]
# ##  Checking whether all the directors present in the movies dataframe are also present in the directors dataframe.

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
directors["id"].nunique()
# Out:
# 2349

# %%
movies["director_id"].isin(directors["id"]).all()
# Out:
# True

# %% [markdown]
# ## Merging both Dataframes together

# %%
df = movies.merge(directors,
                  left_on = "director_id",
                  right_on = "id",
                  how = "left",
                  suffixes = ["_movies","_directors"]
                  )
df
# Out:
#       id_movies     budget  popularity     revenue  \
# 0         43597  237000000         150  2787965087
# 1         43598  300000000         139   961000000
# 2         43599  245000000         107   880674609
# 3         43600  250000000         112  1084939099
# 4         43602  258000000         115   890871626
# ...         ...        ...         ...         ...
# 1460      48363          0           3      321952
# 1461      48370      27000          19     3151130
# 1462      48375          0           7           0
# 1463      48376          0           3           0
# 1464      48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(columns = ["director_id","id_directors"], inplace = True)

# Since we have director's names, we don't need their IDs

# %%
df.head()
# Out:
#    id_movies     budget  popularity     revenue  \
# 0      43597  237000000         150  2787965087
# 1      43598  300000000         139   961000000
# 2      43599  245000000         107   880674609
# 3      43600  250000000         112  1084939099
# 4      43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# ...

# %% [markdown]
# ## Renaming the column

# %%
df.rename(columns = {"id_movies":"movies_id"}, inplace = True)

# %%
df.head()
# Out:
#    movies_id     budget  popularity     revenue  \
# 0      43597  237000000         150  2787965087
# 1      43598  300000000         139   961000000
# 2      43599  245000000         107   880674609
# 3      43600  250000000         112  1084939099
# 4      43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# ...

# %% [markdown]
# ## Converting budget and revenue into millions

# %%
df["budget"] = round(df["budget"]/1000000,2)

# %%
df["revenue"] = round(df["revenue"]/1000000,2)

# %%
df.head()
# Out:
#    movies_id  budget  popularity  revenue  \
# 0      43597   237.0         150  2787.97
# 1      43598   300.0         139   961.00
# 2      43599   245.0         107   880.67
# 3      43600   250.0         112  1084.94
# 4      43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
df.rename(columns = {"budget":"budget_mil","revenue":"revenue_mil"}, inplace = True)

# %%
df.head() # Now we have a clean and nice data for analysis
# Out:
#    movies_id  budget_mil  popularity  revenue_mil  \
# 0      43597       237.0         150      2787.97
# 1      43598       300.0         139       961.00
# 2      43599       245.0         107       880.67
# 3      43600       250.0         112      1084.94
# 4      43602       258.0         115       890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# ...

# %% [markdown]
# ## Identify and list the top 5 movies with the highest popularity scores.

# %%
df.sort_values(by = "popularity", ascending = False)[["title","popularity"]].head()
# Out:
#                                                  title  popularity
# 58                                        Interstellar         724
# 78                                  Mad Max: Fury Road         434
# 119  Pirates of the Caribbean: The Curse of the Bla...         271
# 120              The Hunger Games: Mockingjay - Part 1         206
# 45                                     The Dark Knight         187

# %% [markdown]
# ## Find and list the movies with the highest vote average ratings.

# %%
df.loc[df["vote_average"] >= 7,["title"]]
# Out:
#                                            title
# 0                                         Avatar
# 3                          The Dark Knight Rises
# 8     Pirates of the Caribbean: Dead Man's Chest
# 14     The Hobbit: The Battle of the Five Armies
# 16           The Hobbit: The Desolation of Smaug
# ...                                          ...
# 1456                                  Eraserhead
# 1457                                  The Mighty
# 1458                                          Pi
# 1460                              The Last Waltz
# 1461                                      Clerks
#
# [363 rows x 1 columns]

# %% [markdown]
# ## Calculate number of movies released in each year.

# %%
df.groupby(["year"]).agg(
    no_of_movies = ("title","count")).sort_values(
        by = "year", ascending = False).reset_index().head(10)
# Out:
#    year  no_of_movies
# 0  2016            26
# 1  2015            41
# 2  2014            53
# 3  2013            57
# 4  2012            49
# 5  2011            67
# 6  2010            63
# 7  2009            66
# 8  2008            67
# 9  2007            54

# %% [markdown]
# ## Identify directors who have the highest number of movies in the dataset.

# %%
df.groupby(["director_name"]).agg(
    no_of_movies = ("title","count")).sort_values(
       by = "no_of_movies", ascending = False).reset_index().head()
# Out:
#       director_name  no_of_movies
# 0  Steven Spielberg            26
# 1    Clint Eastwood            19
# 2   Martin Scorsese            19
# 3       Woody Allen            18
# 4  Robert Rodriguez            16

# %% [markdown]
# ## Find directors known for producing high-budget movies by analyzing the budget of movies they've directed.

# %%
df.sort_values(by = "budget_mil", ascending = False)[["director_name","budget_mil"]].head()
# Out:
#      director_name  budget_mil
# 12    Rob Marshall       380.0
# 1   Gore Verbinski       300.0
# 6     Bryan Singer       270.0
# 4        Sam Raimi       258.0
# 9   Gore Verbinski       255.0

# %% [markdown]
# ## find out latest highly rated movies
#
# latest--> after 2014
#
# highly rated movies --> 7+

# %%
df.loc[(df["year"]>2014) & (df["vote_average"]>7)]
# Out:
#       movies_id  budget_mil  popularity  revenue_mil                    title  \
# 30        43641       190.0         102      1506.25                Furious 7
# 78        43724       150.0         434       378.86       Mad Max: Fury Road
# 106       43773       135.0         100       532.95             The Revenant
# 162       43867       108.0         167       630.16              The Martian
# 312       44128        75.0          48       108.15  The Man from U.N.C.L.E.
# 394       44281        44.0          68       155.76        The Hateful Eight
# 625       44770        35.0          53       194.56               The Intern
# 635       44784        40.0          48       165.48          Bridge of Spies
# 808       45194        30.0          65        91.71                 Southpaw
# 833       45293        28.0          61       201.63   Straight Outta Compton
# 839       45301        28.0          57       133.35            The Big Short
# ...

# %% [markdown]
# ## Calculate profit for each movie

# %%
def calculate_profit(x):
  return x["revenue_mil"]-x["budget_mil"]

# %%
df["profit"] = df[["revenue_mil","budget_mil"]].apply(calculate_profit, axis = 1)

# %%
df.head()
# Out:
#    movies_id  budget_mil  popularity  revenue_mil  \
# 0      43597       237.0         150      2787.97
# 1      43598       300.0         139       961.00
# 2      43599       245.0         107       880.67
# 3      43600       250.0         112      1084.94
# 4      43602       258.0         115       890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender   profit
# 0   Dec  Thursday      James Cameron   Male  2550.97
# 1   May  Saturday     Gore Verbinski   Male   661.00
# ...

# %% [markdown]
# ## Most 5 profitable movies

# %%
df.sort_values(by = "profit", ascending = False)[["title","profit"]].head() # Here Profit is also in millions
# Out:
#                                              title   profit
# 0                                           Avatar  2550.97
# 19                                         Titanic  1645.03
# 30                                       Furious 7  1316.25
# 199  The Lord of the Rings: The Return of the King  1024.89
# 36                  Transformers: Dark of the Moon   928.75

# %% [markdown]
# ## find out all the highest rated movies year wise

# %%
highly_rated_movies = df.sort_values(by = ["year","vote_average"], ascending = [True,False])

# %%
highly_rated_movies.drop_duplicates(subset = ["year"], keep = "first") # highly rated movies year wise
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 1427      47934         1.3          58        28.26
# 1368      47336         4.0          35        38.25
# 1460      48363         0.0           3         0.32
# 772       45122        31.5          49        89.46
# 1340      47167         5.0          30        26.01
# 1216      46457        14.0          26        85.00
# 856       45322        28.0          94        33.14
# 919       45447        25.0          70        65.88
# 1320      47036         6.4          74        78.37
# 1061      45882        19.0          76       381.11
# 1286      46836         8.0          51        52.29
# 905       45425        25.0          38        76.27
# 898       45409        25.0          49       412.80
# 552       44603        48.0          80       474.17
# 917       45444        25.0          63        46.84
# 1000      45688        19.0          18       272.74
# 1426      47897         1.2          66        14.66
# ...

# %% [markdown]
# ## Get all the records where director is James Cameron

# %%
df.loc[df["director_name"] == "James Cameron"]
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 0         43597       237.0         150      2787.97
# 19        43622       200.0         100      1845.03
# 170       43876       100.0         101       520.00
# 173       43879       115.0          38       378.88
# 344       44184        70.0          24        90.00
# 1100      46000        18.5          67       183.32
# 1320      47036         6.4          74        78.37
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 19                       Titanic           7.5        7562  1997   Nov
# 170   Terminator 2: Judgment Day           7.7        4185  1991   Jul
# 173                    True Lies           6.8        1116  1994   Jul
# 344                    The Abyss           7.1         808  1989   Aug
# 1100                      Aliens           7.7        3220  1986   Jul
# ...

# %% [markdown]
# ## Calculate the career span and productivity for the same director
#
#
# Career span: The total number of years they have devoted to the industry.
#
# Productivity: Calculated as the total number of movies released by the director divided by career span.

# %%
df_jc = df.loc[df["director_name"] == "James Cameron"]
df_jc
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 0         43597       237.0         150      2787.97
# 19        43622       200.0         100      1845.03
# 170       43876       100.0         101       520.00
# 173       43879       115.0          38       378.88
# 344       44184        70.0          24        90.00
# 1100      46000        18.5          67       183.32
# 1320      47036         6.4          74        78.37
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 19                       Titanic           7.5        7562  1997   Nov
# 170   Terminator 2: Judgment Day           7.7        4185  1991   Jul
# 173                    True Lies           6.8        1116  1994   Jul
# 344                    The Abyss           7.1         808  1989   Aug
# 1100                      Aliens           7.7        3220  1986   Jul
# ...

# %%
df_jc["year"].max()
# Out:
# 2009

# %%
df_jc["year"].min()
# Out:
# 1984

# %%
career_span = df_jc["year"].max() - df_jc["year"].min()
career_span
# Out:
# 25

# %%
df_jc["title"].nunique()
# Out:
# 7

# %%
productivity = df_jc["title"].nunique()/career_span
productivity
# Out:
# 0.28

# %% [markdown]
# ## Calculate career span and productivity for all the directors

# %%
df.groupby(["director_name"]).ngroups # Total no. of unique directors present in the dataframe
# Out:
# 199

# %%
df.groupby(["director_name"]).groups # All directors with their set of index
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
directors_productivity = df.groupby(["director_name"]).agg(year_max = ("year","max"),
                                    year_min = ("year", "min"),title_count = ("title","count")).reset_index()
directors_productivity
# Out:
#                    director_name  year_max  year_min  title_count
# 0                     Adam McKay      2015      2004            6
# 1                  Adam Shankman      2012      2001            8
# 2    Alejandro González Iñárritu      2015      2000            6
# 3                    Alex Proyas      2016      1994            5
# 4                Alexander Payne      2013      1999            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      2011      1984           10
# 195            Wolfgang Petersen      2006      1981            7
# 196                  Woody Allen      2013      1977           18
# 197                  Zack Snyder      2016      2004            7
# 198                  Zhang Yimou      2014      2002            6
#
# [199 rows x 4 columns]

# %%
directors_productivity["career_span"] = directors_productivity["year_max"] - directors_productivity["year_min"]
directors_productivity["productivity"] = directors_productivity["title_count"]/directors_productivity["career_span"]

# %%
directors_productivity
# Out:
#                    director_name  year_max  year_min  title_count  \
# 0                     Adam McKay      2015      2004            6
# 1                  Adam Shankman      2012      2001            8
# 2    Alejandro González Iñárritu      2015      2000            6
# 3                    Alex Proyas      2016      1994            5
# 4                Alexander Payne      2013      1999            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      2011      1984           10
# 195            Wolfgang Petersen      2006      1981            7
# 196                  Woody Allen      2013      1977           18
# 197                  Zack Snyder      2016      2004            7
# 198                  Zhang Yimou      2014      2002            6
#
#      career_span  productivity
# 0             11      0.545455
# 1             11      0.727273
# 2             15      0.400000
# 3             22      0.227273
# ...

# %%
directors_productivity.sort_values(by = "productivity", ascending = False) # High productivity directors
# Out:
#         director_name  year_max  year_min  title_count  career_span  \
# 190       Tyler Perry      2013      2006            9            7
# 73    Jason Friedberg      2010      2006            5            4
# 169        Shawn Levy      2014      2002           11           12
# 158  Robert Rodriguez      2014      1992           16           22
# 1       Adam Shankman      2012      2001            8           11
# ..                ...       ...       ...          ...          ...
# 104   Lawrence Kasdan      2012      1985            5           27
# 109        Luc Besson      2014      1985            5           29
# 157    Robert Redford      2010      1980            5           30
# 170      Sidney Lumet      2006      1976            5           30
# 117     Michael Apted      2010      1980            5           30
#
#      productivity
# 190      1.285714
# 73       1.250000
# 169      0.916667
# 158      0.727273
# 1        0.727273
# ..            ...
# ...

# %% [markdown]
# ## find out all the movies created by high budgedirector
#
#  high budget director --> he has created a movie of budget >=100 Mil $ atleast once in his life

# %%
high_budget_directors = df.groupby(["director_name"]).filter(lambda x: x["budget_mil"].max()>= 100)

# %%
high_budget_directors
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 0         43597      237.00         150      2787.97
# 1         43598      300.00         139       961.00
# 2         43599      245.00         107       880.67
# 3         43600      250.00         112      1084.94
# 4         43602      258.00         115       890.87
# ...         ...         ...         ...          ...
# 1450      48267        0.40          33       100.00
# 1451      48268        0.20          13         4.51
# 1452      48274        0.00           5         2.61
# 1458      48335        0.06          27         3.22
# 1460      48363        0.00           3         0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
high_budget_directors["director_name"].nunique() # Total number of unique high budget directors
# Out:
# 85

# %%
df["director_name"].nunique()
# Out:
# 199

# %% [markdown]
# * Out 199 directors, only 85 directors are the high budget directors

# %%
high_budget_directors["director_name"].unique() # These are the all unique high budget directors
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes',
#        'Christopher Nolan', 'Sam Raimi', 'Zack Snyder', 'Bryan Singer',
#        'Marc Forster', 'Andrew Adamson', 'Rob Marshall',
#        'Barry Sonnenfeld', 'Peter Jackson', 'Ridley Scott', 'Chris Weitz',
#        'Peter Berg', 'Tim Burton', 'Brett Ratner', 'Michael Bay',
#        'Martin Campbell', 'McG', 'James Wan', 'Mike Newell',
#        'Guillermo del Toro', 'Steven Spielberg', 'Justin Lin',
#        'Roland Emmerich', 'Robert Zemeckis', 'Lilly Wachowski',
#        'Jon Favreau', 'Martin Scorsese', 'Rob Cohen', 'David Ayer',
#        'Tom Shadyac', 'Doug Liman', 'Kevin Reynolds', 'David Fincher',
#        'Francis Lawrence', 'Jon Turteltaub', 'Wolfgang Petersen',
#        'Michael Apted', 'Oliver Stone', 'Shawn Levy', 'George Miller',
#        'Ron Howard', 'Kenneth Branagh', 'Jonathan Liebesman',
#        'M. Night Shyamalan', 'Joe Wright', 'Rob Minkoff', 'Lee Tamahori',
# ...

# %% [markdown]
# ## Calculate all the risky movies
#
# risky movies = budget > revenue

# %%
def calculate_risky_movies(x):
  x["risky"] = (x["budget_mil"]-x["revenue_mil"].mean())>=0
  return x

# %%
risky_movies = df.groupby(["director_name"]).apply(calculate_risky_movies)

# %%
risky_movies
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 0         43597      237.00         150      2787.97
# 1         43598      300.00         139       961.00
# 2         43599      245.00         107       880.67
# 3         43600      250.00         112      1084.94
# 4         43602      258.00         115       890.87
# ...         ...         ...         ...          ...
# 1460      48363        0.00           3         0.32
# 1461      48370        0.03          19         3.15
# 1462      48375        0.00           7         0.00
# 1463      48376        0.00           3         0.00
# 1464      48395        0.22          14         2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
risky_movies["risky"] == True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: risky, Length: 1465, dtype: bool

# %%
risky_movies.loc[risky_movies["risky"] == True]
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 7         43608       200.0         107       586.09
# 12        43614       380.0         135      1045.71
# 15        43618       200.0          37       310.67
# 20        43624       209.0          64       303.03
# 24        43630       210.0           3       459.36
# ...         ...         ...         ...          ...
# 1347      47224         5.0           7         3.26
# 1349      47229         5.0           3         4.84
# 1351      47233         5.0           6         0.00
# 1356      47263        15.0          10         0.00
# 1383      47453         3.5           4         0.00
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# ...

# %%
risky_movies.loc[risky_movies["risky"] == True]["title"].nunique() # Total number of unique risky movies
# Out:
# 131

# %%
df.shape
# Out:
# (1465, 13)

# %% [markdown]
# * Out of 1465, 131 movies are the risky movies

# %%
risky_movies.loc[risky_movies["risky"] == True]["title"].unique() # These are the all unique risky movies
# Out:
# array(['Quantum of Solace', 'Pirates of the Caribbean: On Stranger Tides',
#        'Robin Hood', 'Battleship', 'X-Men: The Last Stand',
#        'Terminator Salvation', 'World War Z', 'Hugo', 'Waterworld',
#        'Alexander', 'Thor', 'Pan', 'Die Another Day', 'Lethal Weapon 4',
#        'The Incredible Hulk', 'Clash of the Titans', 'The 13th Warrior',
#        'Batman & Robin', 'Fantastic 4: Rise of the Silver Surfer',
#        "Dante's Peak", 'The Aviator', 'Town & Country', 'Little Fockers',
#        'End of Days', 'Cloud Atlas', 'The Flowers of War',
#        'The Stepford Wives', 'Cutthroat Island', 'Mission to Mars',
#        'Mission: Impossible', "Charlotte's Web", 'Flubber',
#        'Lost in Space', 'The Brothers Grimm', 'Thirteen Days',
#        'Looney Tunes: Back in Action', 'A Sound of Thunder',
#        'Exorcist: The Beginning', "Charlie Wilson's War", 'Driven',
#        'Die Hard 2', 'Doom', 'The Legend of Hercules', 'The Score',
# ...

# %% [markdown]
# ## Get the movies released only on Saturdays or Sundays

# %%
df.loc[(df["day"] == "Saturday") | (df["day"] == "Sunday")]
# Out:
#       movies_id  budget_mil  popularity  revenue_mil  \
# 1         43598      300.00         139       961.00
# 12        43614      380.00         135      1045.71
# 40        43656      200.00          45       769.65
# 51        43670      175.00          27       173.00
# 69        43709      155.00          39       167.30
# ...         ...         ...         ...          ...
# 1442      48185        0.86           3         2.45
# 1444      48204        0.31           1         1.28
# 1447      48231        0.00           3         0.00
# 1456      48321        0.01          20         7.00
# 1459      48359        0.00           2         0.00
#
#                                             title  vote_average  vote_count  \
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 40                                           2012           5.6        4903
# ...

# %%
df.loc[(df["day"] == "Saturday") | (df["day"] == "Sunday")]["title"].nunique()
# Out:
# 93

# %%
df.shape
# Out:
# (1465, 13)

# %% [markdown]
# * Out of 1465, only 93 movies got released on Saturdays or Sundays

# %%
df.loc[(df["day"] == "Saturday") | (df["day"] == "Sunday")]["title"].unique()

# Total unique movies released on Saturdays or Sundays
# Out:
# array(["Pirates of the Caribbean: At World's End",
#        'Pirates of the Caribbean: On Stranger Tides', '2012',
#        'Evan Almighty', 'Alexander',
#        'Harry Potter and the Goblet of Fire', 'Die Another Day',
#        "Legend of the Guardians: The Owls of Ga'Hoole",
#        'Gangs of New York', 'The Lovely Bones', 'Tropic Thunder',
#        'Spy Game', 'The Fast and the Furious: Tokyo Drift', 'Jumper',
#        'Con Air', 'The Edge', 'Thirteen Days', 'A Sound of Thunder',
#        'Red Dragon', 'War Horse', 'Zathura: A Space Adventure', '300',
#        'The Twilight Saga: New Moon', 'Non-Stop', 'Blood Work',
#        'Zoolander 2', 'Extremely Loud & Incredibly Close', 'Gattaca',
#        'Spy Kids', 'House of Wax', 'A Good Year', 'Snakes on a Plane',
#        'Up in the Air', 'Drag Me to Hell', 'Stranger Than Fiction',
#        'Octopussy', 'Freaky Friday', 'The Curse of the Jade Scorpion',
#        'Rain Man', 'The Face of an Angel', 'The Omen',
# ...

# %%
df.head()
# Out:
#    movies_id  budget_mil  popularity  revenue_mil  \
# 0      43597       237.0         150      2787.97
# 1      43598       300.0         139       961.00
# 2      43599       245.0         107       880.67
# 3      43600       250.0         112      1084.94
# 4      43602       258.0         115       890.87
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender   profit   profit
# 0   Dec  Thursday      James Cameron   Male  2550.97  2550.97
# 1   May  Saturday     Gore Verbinski   Male   661.00   661.00
# ...

# %% [markdown]
# _____ THE END _______
